# %%
import os
import yaml
import pandas as pd
import numpy as np
import json
import requests
import pickle
import Levenshtein
from collections import defaultdict
pd.set_option('display.max_columns', None)
import jellyfish
import seaborn as sns
import matplotlib.pyplot as plt



from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %%
folder_path = 'data/csv_data/IPL/match_ball'
all_matches_data_list=[]

# %%
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        with open(os.path.join(folder_path, filename), 'r') as f:
            data = pd.read_csv(f)
        all_matches_data_list.append(data)

# %%
ball_df=all_matches_data_list[0]
match_df=all_matches_data_list[1]

# %%
ball_df['extra_type']=ball_df['extra_type'].fillna('legal')
ball_df['player_out']=ball_df['extra_type'].fillna('No')
ball_df['kind']=ball_df['kind'].fillna('Not Out')
ball_df['fielders_involved']=ball_df['fielders_involved'].fillna('NA')
ball_df.isna().sum()
# Out:
# ID                   0
# innings              0
# overs                0
# ballnumber           0
# batter               0
# bowler               0
# non-striker          0
# extra_type           0
# batsman_run          0
# extras_run           0
# total_run            0
# non_boundary         0
# isWicketDelivery     0
# player_out           0
# kind                 0
# fielders_involved    0
# BattingTeam          0
# dtype: int64

# %%
match_df_=match_df.drop('City',axis=1)
match_df_['SuperOver']=match_df_['SuperOver'].fillna('N')
match_df_['WinningTeam']=match_df_['WinningTeam'].fillna('NA')
match_df_['Player_of_Match']=match_df_['Player_of_Match'].fillna('NA')
match_df_['Margin']=match_df_['Margin'].fillna(0)
match_df_['method']=match_df_['method'].fillna('NA')

# %%
team_1=match_df_['Team1'].unique()
team_2=match_df_['Team2'].unique()
batting_team=ball_df['BattingTeam'].unique()
team_dic={'Kings XI Punjab':'Punjab Kings','Delhi Daredevils':'Delhi Capitals','Pune Warriors':'Rising Pune Supergiants',
           'Deccan Chargers':'Sunrisers Hyderabad','Gujarat Lions':'Gujarat Titans',
            'Rising Pune Supergiant':'Rising Pune Supergiants'}
#batting_team

# %%
match_df_['Team1'] = match_df_['Team1'].replace(team_dic)
match_df_['Team2'] = match_df_['Team2'].replace(team_dic)
match_df_['TossWinner'] = match_df_['TossWinner'].replace(team_dic)


ball_df['BattingTeam'] = ball_df['BattingTeam'].replace(team_dic)
batting_team=match_df_['Team1'].unique()
batting_team
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiants',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
venue_name_replacements = {
    'Narendra Modi Stadium, Ahmedabad': 'Narendra Modi Stadium',
    'Eden Gardens, Kolkata': 'Eden Gardens',
    'Wankhede Stadium, Mumbai': 'Wankhede Stadium',
    'Brabourne Stadium, Mumbai': 'Brabourne Stadium',
    'Dr DY Patil Sports Academy, Mumbai': 'Dr DY Patil Sports Academy',
    'Maharashtra Cricket Association Stadium, Pune': 'Maharashtra Cricket Association Stadium',
    'Dubai International Cricket Stadium': 'Dubai International Cricket Stadium',
    'Sharjah Cricket Stadium': 'Sharjah Cricket Stadium',
    'Zayed Cricket Stadium, Abu Dhabi': 'Zayed Cricket Stadium',
    'Arun Jaitley Stadium, Delhi': 'Arun Jaitley Stadium',
    'MA Chidambaram Stadium, Chepauk, Chennai': 'MA Chidambaram Stadium',
    'Sheikh Zayed Stadium': 'Sheikh Zayed Stadium',
    'Rajiv Gandhi International Stadium': 'Rajiv Gandhi International Stadium',
    'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
    'MA Chidambaram Stadium': 'MA Chidambaram Stadium',
    'Punjab Cricket Association IS Bindra Stadium': 'Punjab Cricket Association IS Bindra Stadium',
    'M.Chinnaswamy Stadium': 'M Chinnaswamy Stadium',
    'Arun Jaitley Stadium': 'Arun Jaitley Stadium',
    'Eden Gardens': 'Eden Gardens',
    'Sawai Mansingh Stadium': 'Sawai Mansingh Stadium',
    'Maharashtra Cricket Association Stadium': 'Maharashtra Cricket Association Stadium',
    'Holkar Cricket Stadium': 'Holkar Cricket Stadium',
    'Rajiv Gandhi International Stadium, Uppal': 'Rajiv Gandhi International Stadium',
    'M Chinnaswamy Stadium': 'M Chinnaswamy Stadium',
    'Feroz Shah Kotla': 'Feroz Shah Kotla',
    'Green Park': 'Green Park',
    'Punjab Cricket Association IS Bindra Stadium, Mohali': 'Punjab Cricket Association IS Bindra Stadium',
    'Saurashtra Cricket Association Stadium': 'Saurashtra Cricket Association Stadium',
    'Shaheed Veer Narayan Singh International Stadium': 'Shaheed Veer Narayan Singh International Stadium',
    'JSCA International Stadium Complex': 'JSCA International Stadium Complex',
    'Brabourne Stadium': 'Brabourne Stadium',
    'Punjab Cricket Association Stadium, Mohali': 'Punjab Cricket Association Stadium',
    'MA Chidambaram Stadium, Chepauk': 'MA Chidambaram Stadium',
    'Sardar Patel Stadium, Motera': 'Sardar Patel Stadium',
    'Barabati Stadium': 'Barabati Stadium',
    'Subrata Roy Sahara Stadium': 'Subrata Roy Sahara Stadium',
    'Himachal Pradesh Cricket Association Stadium': 'Himachal Pradesh Cricket Association Stadium',
    'Dr DY Patil Sports Academy': 'Dr DY Patil Sports Academy',
    'Nehru Stadium': 'Nehru Stadium',
    'Vidarbha Cricket Association Stadium, Jamtha': 'Vidarbha Cricket Association Stadium',
    'New Wanderers Stadium': 'New Wanderers Stadium',
    'SuperSport Park': 'SuperSport Park'
}

# %%
match_df_['Venue'] = match_df_['Venue'].replace(venue_name_replacements)
venues=match_df_['Venue'].unique()
#venues

# %%
ball_df['extra_type']=ball_df['extra_type'].fillna('legal')
ball_df['player_out']=ball_df['extra_type'].fillna('No')
ball_df['kind']=ball_df['kind'].fillna('Not Out')
ball_df['fielders_involved']=ball_df['fielders_involved'].fillna('NA')
ball_df.isna().sum()
# Out:
# ID                   0
# innings              0
# overs                0
# ballnumber           0
# batter               0
# bowler               0
# non-striker          0
# extra_type           0
# batsman_run          0
# extras_run           0
# total_run            0
# non_boundary         0
# isWicketDelivery     0
# player_out           0
# kind                 0
# fielders_involved    0
# BattingTeam          0
# dtype: int64

# %%
merged_df = match_df.merge(ball_df, on='ID')
merged_df['Venue'] = merged_df['Venue'].replace(venue_name_replacements)
# Printing the merged dataframe
print(merged_df.isna().sum())
# Out:
# ID                        0
# City                  12397
# Date                      0
# Season                    0
# MatchNumber               0
# Team1                     0
# Team2                     0
# Venue                     0
# TossWinner                0
# TossDecision              0
# SuperOver               372
# WinningTeam             372
# WonBy                     0
# Margin                 4006
# method               222746
# Player_of_Match         372
# Team1Players              0
# Team2Players              0
# Umpire1                   0
# Umpire2                   0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type                0
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out                0
# kind                      0
# fielders_involved         0
# BattingTeam               0
# dtype: int64

# %%
merged_df=merged_df.drop('City',axis=1)
merged_df['SuperOver']=merged_df['SuperOver'].fillna('N')
merged_df['WinningTeam']=merged_df['WinningTeam'].fillna('NA')
merged_df['Player_of_Match']=merged_df['Player_of_Match'].fillna('NA')
merged_df['Margin']=merged_df['Margin'].fillna(0)
merged_df['method']=merged_df['method'].fillna('NA')
merged_df.isna().sum()
# Out:
# ID                   0
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            0
# WinningTeam          0
# WonBy                0
# Margin               0
# method               0
# Player_of_Match      0
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# innings              0
# overs                0
# ballnumber           0
# batter               0
# bowler               0
# non-striker          0
# extra_type           0
# batsman_run          0
# extras_run           0
# total_run            0
# non_boundary         0
# isWicketDelivery     0
# player_out           0
# kind                 0
# fielders_involved    0
# BattingTeam          0
# dtype: int64

# %%
# Group the data by match id and inning
grouped_data = merged_df.groupby(['ID', 'innings'])

# Create an empty list to store the powerplay data
batter_powerplay_data = []
bowler_powerplay_data = []
powerplay_data=[]
# Loop through each group
for name, group in grouped_data:
    #print(name)
    #print(group)
    # Filter out the ball-by-ball data for the first 6 overs of the innings
    powerplay = group.loc[group['overs'] <= 5]
    
    total_powerplay_score=powerplay.groupby(['ID','innings'])['total_run'].sum()
    #print(total_powerplay_score.values)
    
    # Calculate the total runs and balls faced by each batsman
    runs = powerplay.groupby('batter')['batsman_run'].sum()
    balls_faced = powerplay.groupby('batter')['isWicketDelivery'].count()
    
    # Calculate the strike rate of each batsman
    batter_strike_rate = (runs / balls_faced) * 100
    #print(batter_strike_rate)
    
    # Calculate the total runs and overs bowled by each bowler
    runs_conceded = powerplay.groupby('bowler')['total_run'].sum()
    overs_bowled = powerplay.groupby('bowler')['overs'].nunique()
    wicket_taken = powerplay.groupby('bowler')['isWicketDelivery'].sum()
    # Calculate the economy rate of each bowler
    economy_rate = runs_conceded / overs_bowled
    bowler_strike_rate = overs_bowled*6 / wicket_taken
    
    #print(strike_rate.index)
    #print(economy_rate)
    
    #print(bowler_strike_rate)
    #print
    #'''
    #try:
    # Create a new dataframe with the powerplay statistics
    powerplay_score=pd.DataFrame({
        'Powerplay Score': total_powerplay_score.values
    })
    powerplay_score['ID']=name[0]
    powerplay_score['Innings']=name[1]
    
    batter_powerplay_stats = pd.DataFrame({
        'Batsman': batter_strike_rate.index,
        'Batter Strike Rate': batter_strike_rate.values
    })
    batter_powerplay_stats['ID']=name[0]
    batter_powerplay_stats['Innings']=name[1]

    #print(batter_powerplay_stats)

    bowler_powerplay_stats = pd.DataFrame({
        'Bowler': economy_rate.index,
        'Economy Rate': economy_rate.values,
        'Bowler Strike Rate': bowler_strike_rate.values,
    })

    bowler_powerplay_stats['ID']=name[0]
    bowler_powerplay_stats['Innings']=name[1]
        
        #print(bowler_powerplay_stats)
        
    #except ValueError as e:
        #print('Match ID',name[0])
        #print('Inning',name[1])
        #break
        #print(e)
        #print(batter_powerplay_stats)
        #print(bowler_powerplay_stats)
    
    # Append the powerplay statistics to the powerplay data list
    powerplay_data.append(powerplay_score)
    batter_powerplay_data.append(batter_powerplay_stats)
    bowler_powerplay_data.append(bowler_powerplay_stats)

# Concatenate the powerplay data into a single dataframe

#'''

# %%
batter_powerplay=pd.concat(batter_powerplay_data)
bowler_powerplay=pd.concat(bowler_powerplay_data)
total_powerplay=pd.concat(powerplay_data)

#print(batter_powerplay.columns)
#print(bowler_powerplay.columns)



powerplay_df = pd.merge(batter_powerplay,bowler_powerplay,on=['ID','Innings'])
powerplay_df = pd.merge(powerplay_df,total_powerplay,on=['ID','Innings'])

#print(powerplay_df.columns)


powerplay_stats_df = powerplay_df.merge(match_df_, on=['ID'])

powerplay_stats_df
# Out:
#             Batsman  Batter Strike Rate       ID  Innings             Bowler  \
# 0       BB McCullum          186.363636   335982        1          AA Noffke
# 1       BB McCullum          186.363636   335982        1            P Kumar
# 2       BB McCullum          186.363636   335982        1             Z Khan
# 3        RT Ponting            0.000000   335982        1          AA Noffke
# 4        RT Ponting            0.000000   335982        1            P Kumar
# ...             ...                 ...      ...      ...                ...
# 22403  Shubman Gill           71.428571  1312200        2           TA Boult
# 22404  Shubman Gill           71.428571  1312200        2          YS Chahal
# 22405       WP Saha           71.428571  1312200        2  M Prasidh Krishna
# 22406       WP Saha           71.428571  1312200        2           TA Boult
# 22407       WP Saha           71.428571  1312200        2          YS Chahal
#
#        Economy Rate  Bowler Strike Rate  Powerplay Score        Date   Season  \
# 0         23.000000                 inf               61  2008-04-18  2007/08
# 1          6.333333                 inf               61  2008-04-18  2007/08
# 2          9.500000                12.0               61  2008-04-18  2007/08
# 3         23.000000                 inf               61  2008-04-18  2007/08
# 4          6.333333                 inf               61  2008-04-18  2007/08
# ...             ...                 ...              ...         ...      ...
# 22403      2.666667                18.0               31  2022-05-29     2022
# 22404      6.000000                 inf               31  2022-05-29     2022
# 22405      8.500000                12.0               31  2022-05-29     2022
# 22406      2.666667                18.0               31  2022-05-29     2022
# 22407      6.000000                 inf               31  2022-05-29     2022
#
#       MatchNumber                        Team1                  Team2  \
# 0               1  Royal Challengers Bangalore  Kolkata Knight Riders
# 1               1  Royal Challengers Bangalore  Kolkata Knight Riders
# 2               1  Royal Challengers Bangalore  Kolkata Knight Riders
# 3               1  Royal Challengers Bangalore  Kolkata Knight Riders
# 4               1  Royal Challengers Bangalore  Kolkata Knight Riders
# ...           ...                          ...                    ...
# 22403       Final             Rajasthan Royals         Gujarat Titans
# 22404       Final             Rajasthan Royals         Gujarat Titans
# 22405       Final             Rajasthan Royals         Gujarat Titans
# 22406       Final             Rajasthan Royals         Gujarat Titans
# 22407       Final             Rajasthan Royals         Gujarat Titans
#
#                        Venue                   TossWinner TossDecision  \
# 0      M Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 1      M Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 2      M Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 3      M Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 4      M Chinnaswamy Stadium  Royal Challengers Bangalore        field
# ...                      ...                          ...          ...
# 22403  Narendra Modi Stadium             Rajasthan Royals          bat
# 22404  Narendra Modi Stadium             Rajasthan Royals          bat
# 22405  Narendra Modi Stadium             Rajasthan Royals          bat
# 22406  Narendra Modi Stadium             Rajasthan Royals          bat
# 22407  Narendra Modi Stadium             Rajasthan Royals          bat
#
#       SuperOver            WinningTeam    WonBy  Margin method  \
# 0             N  Kolkata Knight Riders     Runs   140.0     NA
# 1             N  Kolkata Knight Riders     Runs   140.0     NA
# 2             N  Kolkata Knight Riders     Runs   140.0     NA
# 3             N  Kolkata Knight Riders     Runs   140.0     NA
# 4             N  Kolkata Knight Riders     Runs   140.0     NA
# ...         ...                    ...      ...     ...    ...
# 22403         N         Gujarat Titans  Wickets     7.0     NA
# 22404         N         Gujarat Titans  Wickets     7.0     NA
# 22405         N         Gujarat Titans  Wickets     7.0     NA
# 22406         N         Gujarat Titans  Wickets     7.0     NA
# 22407         N         Gujarat Titans  Wickets     7.0     NA
#
#       Player_of_Match                                       Team1Players  \
# 0         BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 1         BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 2         BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 3         BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 4         BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# ...               ...                                                ...
# 22403       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 22404       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 22405       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 22406       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 22407       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                             Team2Players      Umpire1  \
# 0      ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...    Asad Rauf
# 1      ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...    Asad Rauf
# 2      ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...    Asad Rauf
# 3      ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...    Asad Rauf
# 4      ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...    Asad Rauf
# ...                                                  ...          ...
# 22403  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney
# 22404  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney
# 22405  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney
# 22406  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney
# 22407  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney
#
#            Umpire2
# 0      RE Koertzen
# 1      RE Koertzen
# 2      RE Koertzen
# 3      RE Koertzen
# 4      RE Koertzen
# ...            ...
# 22403  Nitin Menon
# 22404  Nitin Menon
# 22405  Nitin Menon
# 22406  Nitin Menon
# 22407  Nitin Menon
#
# [22408 rows x 26 columns]

# %%
median_batter_powerplay=batter_powerplay.groupby(['ID','Innings']).agg({'Batter Strike Rate':'median'}).reset_index()
median_bowler_powerplay=bowler_powerplay.groupby(['ID','Innings']).agg({'Economy Rate':'median'}).reset_index()
#total_powerplay
#median_batter_powerplay

# %%
powerplay_stats_df_v2 = total_powerplay.merge(median_batter_powerplay, on=['ID','Innings'])
powerplay_stats_df_v2 = powerplay_stats_df_v2.merge(median_bowler_powerplay, on=['ID','Innings'])
powerplay_stats_df_v2 = powerplay_stats_df_v2.merge(match_df_, on=['ID'])

# %%
def fetch_batting_team(r):
    if((r['Innings']==1) and (r['TossDecision']=='bat') and (r['TossWinner']==r['Team1'])):
        return r['Team1']
    elif((r['Innings']==1) and (r['TossDecision']=='bat') and (r['TossWinner']==r['Team2'])):
        return r['Team2']
    
    elif((r['Innings']==1) and (r['TossDecision']=='field') and (r['TossWinner']==r['Team1'])):
        return r['Team2']
    elif((r['Innings']==1) and (r['TossDecision']=='field') and (r['TossWinner']==r['Team2'])):
        return r['Team1']
    
    if((r['Innings']==2) and (r['TossDecision']=='bat') and (r['TossWinner']==r['Team1'])):
        return r['Team2']
    elif((r['Innings']==2) and (r['TossDecision']=='bat') and (r['TossWinner']==r['Team2'])):
        return r['Team1']
    
    elif((r['Innings']==2) and (r['TossDecision']=='field') and (r['TossWinner']==r['Team1'])):
        return r['Team1']
    elif((r['Innings']==2) and (r['TossDecision']=='field') and (r['TossWinner']==r['Team2'])):
        return r['Team2']

def fetch_bowling_team(r):
    if((r['Innings']==1) and (r['TossDecision']=='bat') and (r['TossWinner']==r['Team1'])):
        return r['Team2']
    elif((r['Innings']==1) and (r['TossDecision']=='bat') and (r['TossWinner']==r['Team2'])):
        return r['Team1']
    
    elif((r['Innings']==1) and (r['TossDecision']=='field') and (r['TossWinner']==r['Team1'])):
        return r['Team1']
    elif((r['Innings']==1) and (r['TossDecision']=='field') and (r['TossWinner']==r['Team2'])):
        return r['Team1']
    
    if((r['Innings']==2) and (r['TossDecision']=='bat') and (r['TossWinner']==r['Team1'])):
        return r['Team1']
    elif((r['Innings']==2) and (r['TossDecision']=='bat') and (r['TossWinner']==r['Team2'])):
        return r['Team2']
    
    elif((r['Innings']==2) and (r['TossDecision']=='field') and (r['TossWinner']==r['Team1'])):
        return r['Team2']
    elif((r['Innings']==2) and (r['TossDecision']=='field') and (r['TossWinner']==r['Team2'])):
        return r['Team1']

# %%
#venue	innings	batting_team	bowling_team	batsmen	bowlers
#MA Chidambaram Stadium	1	Mumbai Indians	Kolkata Knight Riders	Quinton de Kock, Rohit Sharma, Suryakumar Yadav	Harbhajan Singh, Varun Chakravarthy, Shakib Al Hasan, Pat Cummins
#MA Chidambaram Stadium	2	Kolkata Knight Riders	Mumbai Indians	Harbhajan Singh, Varun Chakravarthy, Shakib Al Hasan, Pat Cummins	Quinton de Kock, Rohit Sharma, Suryakumar Yadav


powerplay_stats_df_v2['Team1']=powerplay_stats_df_v2['Team1'].replace(team_dic)
powerplay_stats_df_v2['Team2']=powerplay_stats_df_v2['Team2'].replace(team_dic)
powerplay_stats_df_v2['batting_team']=powerplay_stats_df_v2.apply(fetch_batting_team,axis=1)
powerplay_stats_df_v2['bowling_team']=powerplay_stats_df_v2.apply(fetch_bowling_team,axis=1)

powerplay_stats_df_v2['TossWinner']=powerplay_stats_df_v2['TossWinner'].replace(team_dic)
powerplay_stats_df_v2['batting_team']=powerplay_stats_df_v2['batting_team'].replace(team_dic)
powerplay_stats_df_v2['bowling_team']=powerplay_stats_df_v2['bowling_team'].replace(team_dic)

powerplay_stats_df_v2['batting_team'].unique()
powerplay_stats_df_v2[powerplay_stats_df_v2['batting_team'].isna()]
# Out:
#       Powerplay Score       ID  Innings  Batter Strike Rate  Economy Rate  \
# 134                15   392190        3          158.333333          15.0
# 135                18   392190        4          450.000000          18.0
# 264                 9   419121        3          100.000000           9.0
# 265                10   419121        4          250.000000          10.0
# 661                20   598004        3          220.000000          20.0
# 662                15   598004        4          250.000000          15.0
# 689                15   598017        3          212.500000          15.0
# 690                11   598017        4            0.000000          11.0
# 841                11   729315        3          100.000000          11.0
# 842                11   729315        4          183.333333          11.0
# 963                15   829741        3          100.000000          15.0
# 964                 6   829741        4            0.000000           6.0
# 1232               11  1082625        3          191.666667          11.0
# 1233                6  1082625        4           25.000000           6.0
# 1424               10  1175365        3          175.000000          10.0
# 1425                7  1175365        4          100.000000           7.0
# 1508                8  1178426        3          100.000000           8.0
# 1509                9  1178426        4          275.000000           9.0
# 1532                2  1216493        3           50.000000           2.0
# 1533                3  1216493        4           66.666667           3.0
# 1572                2  1216512        3           50.000000           2.0
# 1573                3  1216512        4           25.000000           3.0
# 1584                5  1216517        3          100.000000           5.0
# 1585                5  1216517        4           83.333333           5.0
# 1586               11  1216517        5           91.666667          11.0
# 1587               15  1216517        6          375.000000          15.0
# 1648                7  1216547        3           87.500000           7.0
# 1649               11  1216547        4          200.000000          11.0
# 1698                7  1254077        3          100.000000           7.0
# 1699                8  1254077        4           62.500000           8.0
#
#             Date   Season MatchNumber                        Team1  \
# 134   2009-04-23     2009          10        Kolkata Knight Riders
# 135   2009-04-23     2009          10        Kolkata Knight Riders
# 264   2010-03-21  2009/10          16          Chennai Super Kings
# 265   2010-03-21  2009/10          16          Chennai Super Kings
# 661   2013-04-07     2013           7          Sunrisers Hyderabad
# 662   2013-04-07     2013           7          Sunrisers Hyderabad
# 689   2013-04-16     2013          21  Royal Challengers Bangalore
# 690   2013-04-16     2013          21  Royal Challengers Bangalore
# 841   2014-04-29     2014          19        Kolkata Knight Riders
# 842   2014-04-29     2014          19        Kolkata Knight Riders
# 963   2015-04-21     2015          18             Rajasthan Royals
# 964   2015-04-21     2015          18             Rajasthan Royals
# 1232  2017-04-29     2017          35               Gujarat Titans
# 1233  2017-04-29     2017          35               Gujarat Titans
# 1424  2019-03-30     2019          10        Kolkata Knight Riders
# 1425  2019-03-30     2019          10        Kolkata Knight Riders
# 1508  2019-05-02     2019          51               Mumbai Indians
# 1509  2019-05-02     2019          51               Mumbai Indians
# 1532  2020-09-20  2020/21           2               Delhi Capitals
# 1533  2020-09-20  2020/21           2               Delhi Capitals
# 1572  2020-10-18  2020/21          35        Kolkata Knight Riders
# 1573  2020-10-18  2020/21          35        Kolkata Knight Riders
# 1584  2020-10-18  2020/21          36               Mumbai Indians
# 1585  2020-10-18  2020/21          36               Mumbai Indians
# 1586  2020-10-18  2020/21          36               Mumbai Indians
# 1587  2020-10-18  2020/21          36               Mumbai Indians
# 1648  2020-09-28  2020/21          10  Royal Challengers Bangalore
# 1649  2020-09-28  2020/21          10  Royal Challengers Bangalore
# 1698  2021-04-25     2021          20               Delhi Capitals
# 1699  2021-04-25     2021          20               Delhi Capitals
#
#                             Team2                                   Venue  \
# 134              Rajasthan Royals                                Newlands
# 135              Rajasthan Royals                                Newlands
# 264                  Punjab Kings                  MA Chidambaram Stadium
# 265                  Punjab Kings                  MA Chidambaram Stadium
# 661   Royal Challengers Bangalore      Rajiv Gandhi International Stadium
# 662   Royal Challengers Bangalore      Rajiv Gandhi International Stadium
# 689                Delhi Capitals                   M Chinnaswamy Stadium
# 690                Delhi Capitals                   M Chinnaswamy Stadium
# 841              Rajasthan Royals                    Sheikh Zayed Stadium
# 842              Rajasthan Royals                    Sheikh Zayed Stadium
# 963                  Punjab Kings                    Sardar Patel Stadium
# 964                  Punjab Kings                    Sardar Patel Stadium
# 1232               Mumbai Indians  Saurashtra Cricket Association Stadium
# 1233               Mumbai Indians  Saurashtra Cricket Association Stadium
# 1424               Delhi Capitals                    Arun Jaitley Stadium
# 1425               Delhi Capitals                    Arun Jaitley Stadium
# 1508          Sunrisers Hyderabad                        Wankhede Stadium
# 1509          Sunrisers Hyderabad                        Wankhede Stadium
# 1532                 Punjab Kings     Dubai International Cricket Stadium
# 1533                 Punjab Kings     Dubai International Cricket Stadium
# 1572          Sunrisers Hyderabad                    Sheikh Zayed Stadium
# 1573          Sunrisers Hyderabad                    Sheikh Zayed Stadium
# 1584                 Punjab Kings     Dubai International Cricket Stadium
# 1585                 Punjab Kings     Dubai International Cricket Stadium
# 1586                 Punjab Kings     Dubai International Cricket Stadium
# 1587                 Punjab Kings     Dubai International Cricket Stadium
# 1648               Mumbai Indians     Dubai International Cricket Stadium
# 1649               Mumbai Indians     Dubai International Cricket Stadium
# 1698          Sunrisers Hyderabad                  MA Chidambaram Stadium
# 1699          Sunrisers Hyderabad                  MA Chidambaram Stadium
#
#                        TossWinner TossDecision SuperOver  \
# 134         Kolkata Knight Riders        field         Y
# 135         Kolkata Knight Riders        field         Y
# 264           Chennai Super Kings        field         Y
# 265           Chennai Super Kings        field         Y
# 661   Royal Challengers Bangalore          bat         Y
# 662   Royal Challengers Bangalore          bat         Y
# 689   Royal Challengers Bangalore        field         Y
# 690   Royal Challengers Bangalore        field         Y
# 841              Rajasthan Royals          bat         Y
# 842              Rajasthan Royals          bat         Y
# 963                  Punjab Kings        field         Y
# 964                  Punjab Kings        field         Y
# 1232               Gujarat Titans          bat         Y
# 1233               Gujarat Titans          bat         Y
# 1424               Delhi Capitals        field         Y
# 1425               Delhi Capitals        field         Y
# 1508               Mumbai Indians          bat         Y
# 1509               Mumbai Indians          bat         Y
# 1532                 Punjab Kings        field         Y
# 1533                 Punjab Kings        field         Y
# 1572          Sunrisers Hyderabad        field         Y
# 1573          Sunrisers Hyderabad        field         Y
# 1584               Mumbai Indians          bat         Y
# 1585               Mumbai Indians          bat         Y
# 1586               Mumbai Indians          bat         Y
# 1587               Mumbai Indians          bat         Y
# 1648               Mumbai Indians        field         Y
# 1649               Mumbai Indians        field         Y
# 1698               Delhi Capitals          bat         Y
# 1699               Delhi Capitals          bat         Y
#
#                       WinningTeam      WonBy  Margin method Player_of_Match  \
# 134              Rajasthan Royals  SuperOver     0.0     NA       YK Pathan
# 135              Rajasthan Royals  SuperOver     0.0     NA       YK Pathan
# 264               Kings XI Punjab  SuperOver     0.0     NA        J Theron
# 265               Kings XI Punjab  SuperOver     0.0     NA        J Theron
# 661           Sunrisers Hyderabad  SuperOver     0.0     NA       GH Vihari
# 662           Sunrisers Hyderabad  SuperOver     0.0     NA       GH Vihari
# 689   Royal Challengers Bangalore  SuperOver     0.0     NA         V Kohli
# 690   Royal Challengers Bangalore  SuperOver     0.0     NA         V Kohli
# 841              Rajasthan Royals  SuperOver     0.0     NA     JP Faulkner
# 842              Rajasthan Royals  SuperOver     0.0     NA     JP Faulkner
# 963               Kings XI Punjab  SuperOver     0.0     NA        SE Marsh
# 964               Kings XI Punjab  SuperOver     0.0     NA        SE Marsh
# 1232               Mumbai Indians  SuperOver     0.0     NA       KH Pandya
# 1233               Mumbai Indians  SuperOver     0.0     NA       KH Pandya
# 1424               Delhi Capitals  SuperOver     0.0     NA         PP Shaw
# 1425               Delhi Capitals  SuperOver     0.0     NA         PP Shaw
# 1508               Mumbai Indians  SuperOver     0.0     NA       JJ Bumrah
# 1509               Mumbai Indians  SuperOver     0.0     NA       JJ Bumrah
# 1532               Delhi Capitals  SuperOver     0.0     NA      MP Stoinis
# 1533               Delhi Capitals  SuperOver     0.0     NA      MP Stoinis
# 1572        Kolkata Knight Riders  SuperOver     0.0     NA     LH Ferguson
# 1573        Kolkata Knight Riders  SuperOver     0.0     NA     LH Ferguson
# 1584              Kings XI Punjab  SuperOver     0.0     NA        KL Rahul
# 1585              Kings XI Punjab  SuperOver     0.0     NA        KL Rahul
# 1586              Kings XI Punjab  SuperOver     0.0     NA        KL Rahul
# 1587              Kings XI Punjab  SuperOver     0.0     NA        KL Rahul
# 1648  Royal Challengers Bangalore  SuperOver     0.0     NA  AB de Villiers
# 1649  Royal Challengers Bangalore  SuperOver     0.0     NA  AB de Villiers
# 1698               Delhi Capitals  SuperOver     0.0     NA         PP Shaw
# 1699               Delhi Capitals  SuperOver     0.0     NA         PP Shaw
#
#                                            Team1Players  \
# 134   ['CH Gayle', 'BB McCullum', 'LR Shukla', 'BJ H...
# 135   ['CH Gayle', 'BB McCullum', 'LR Shukla', 'BJ H...
# 264   ['PA Patel', 'ML Hayden', 'SK Raina', 'M Vijay...
# 265   ['PA Patel', 'ML Hayden', 'SK Raina', 'M Vijay...
# 661   ['PA Reddy', 'PA Patel', 'CL White', 'GH Vihar...
# 662   ['PA Reddy', 'PA Patel', 'CL White', 'GH Vihar...
# 689   ['CH Gayle', 'KL Rahul', 'V Kohli', 'AB de Vil...
# 690   ['CH Gayle', 'KL Rahul', 'V Kohli', 'AB de Vil...
# 841   ['G Gambhir', 'MS Bisla', 'JH Kallis', 'MK Pan...
# 842   ['G Gambhir', 'MS Bisla', 'JH Kallis', 'MK Pan...
# 963   ['AM Rahane', 'SR Watson', 'DJ Hooda', 'SPD Sm...
# 964   ['AM Rahane', 'SR Watson', 'DJ Hooda', 'SPD Sm...
# 1232  ['Ishan Kishan', 'BB McCullum', 'SK Raina', 'A...
# 1233  ['Ishan Kishan', 'BB McCullum', 'SK Raina', 'A...
# 1424  ['NS Naik', 'CA Lynn', 'RV Uthappa', 'N Rana',...
# 1425  ['NS Naik', 'CA Lynn', 'RV Uthappa', 'N Rana',...
# 1508  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'E Lewi...
# 1509  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'E Lewi...
# 1532  ['PP Shaw', 'S Dhawan', 'SO Hetmyer', 'SS Iyer...
# 1533  ['PP Shaw', 'S Dhawan', 'SO Hetmyer', 'SS Iyer...
# 1572  ['Shubman Gill', 'RA Tripathi', 'N Rana', 'AD ...
# 1573  ['Shubman Gill', 'RA Tripathi', 'N Rana', 'AD ...
# 1584  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 1585  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 1586  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 1587  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 1648  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 1649  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 1698  ['PP Shaw', 'S Dhawan', 'RR Pant', 'SPD Smith'...
# 1699  ['PP Shaw', 'S Dhawan', 'RR Pant', 'SPD Smith'...
#
#                                            Team2Players       Umpire1  \
# 134   ['GC Smith', 'PC Valthaty', 'RJ Quiney', 'YK P...     MR Benson
# 135   ['GC Smith', 'PC Valthaty', 'RJ Quiney', 'YK P...     MR Benson
# 264   ['RS Bopara', 'IK Pathan', 'KC Sangakkara', 'D...   K Hariharan
# 265   ['RS Bopara', 'IK Pathan', 'KC Sangakkara', 'D...   K Hariharan
# 661   ['CH Gayle', 'TM Dilshan', 'V Kohli', 'KK Nair...  AK Chaudhary
# 662   ['CH Gayle', 'TM Dilshan', 'V Kohli', 'KK Nair...  AK Chaudhary
# 689   ['DA Warner', 'V Sehwag', 'MC Juneja', 'DPMD J...     M Erasmus
# 690   ['DA Warner', 'V Sehwag', 'MC Juneja', 'DPMD J...     M Erasmus
# 841   ['AM Rahane', 'KK Nair', 'SV Samson', 'SR Wats...     Aleem Dar
# 842   ['AM Rahane', 'KK Nair', 'SV Samson', 'SR Wats...     Aleem Dar
# 963   ['M Vijay', 'V Sehwag', 'SE Marsh', 'GJ Maxwel...     M Erasmus
# 964   ['M Vijay', 'V Sehwag', 'SE Marsh', 'GJ Maxwel...     M Erasmus
# 1232  ['PA Patel', 'JC Buttler', 'N Rana', 'RG Sharm...  AK Chaudhary
# 1233  ['PA Patel', 'JC Buttler', 'N Rana', 'RG Sharm...  AK Chaudhary
# 1424  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...   AY Dandekar
# 1425  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...   AY Dandekar
# 1508  ['WP Saha', 'MJ Guptill', 'MK Pandey', 'KS Wil...     CK Nandan
# 1509  ['WP Saha', 'MJ Guptill', 'MK Pandey', 'KS Wil...     CK Nandan
# 1532  ['KL Rahul', 'MA Agarwal', 'KK Nair', 'N Poora...  AK Chaudhary
# 1533  ['KL Rahul', 'MA Agarwal', 'KK Nair', 'N Poora...  AK Chaudhary
# 1572  ['JM Bairstow', 'KS Williamson', 'PK Garg', 'D...     PG Pathak
# 1573  ['JM Bairstow', 'KS Williamson', 'PK Garg', 'D...     PG Pathak
# 1584  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...   Nitin Menon
# 1585  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...   Nitin Menon
# 1586  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...   Nitin Menon
# 1587  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...   Nitin Menon
# 1648  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...   Nitin Menon
# 1649  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...   Nitin Menon
# 1698  ['DA Warner', 'JM Bairstow', 'KS Williamson', ...   CB Gaffaney
# 1699  ['DA Warner', 'JM Bairstow', 'KS Williamson', ...   CB Gaffaney
#
#                     Umpire2 batting_team bowling_team
# 134               M Erasmus         None         None
# 135               M Erasmus         None         None
# 264               DJ Harper         None         None
# 265               DJ Harper         None         None
# 661                  S Ravi         None         None
# 662                  S Ravi         None         None
# 689             VA Kulkarni         None         None
# 690             VA Kulkarni         None         None
# 841            AK Chaudhary         None         None
# 842            AK Chaudhary         None         None
# 963                  S Ravi         None         None
# 964                  S Ravi         None         None
# 1232            CB Gaffaney         None         None
# 1233            CB Gaffaney         None         None
# 1424            Nitin Menon         None         None
# 1425            Nitin Menon         None         None
# 1508                 S Ravi         None         None
# 1509                 S Ravi         None         None
# 1532            Nitin Menon         None         None
# 1533            Nitin Menon         None         None
# 1572                 S Ravi         None         None
# 1573                 S Ravi         None         None
# 1584             PR Reiffel         None         None
# 1585             PR Reiffel         None         None
# 1586             PR Reiffel         None         None
# 1587             PR Reiffel         None         None
# 1648             PR Reiffel         None         None
# 1649             PR Reiffel         None         None
# 1698  KN Ananthapadmanabhan         None         None
# 1699  KN Ananthapadmanabhan         None         None

# %%
powerplay_stats_df_v2.columns
# Out:
# Index(['Powerplay Score', 'ID', 'Innings', 'Batter Strike Rate',
#        'Economy Rate', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'batting_team', 'bowling_team'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20, 15))
sns.boxplot(x='batting_team', y='Batter Strike Rate', hue='Innings', data=powerplay_stats_df_v2)
plt.xlabel('Inning')
plt.ylabel('Score')
plt.xticks(rotation=90)
plt.title('Team Strike Rate by Inning')
plt.show()

# %%
fig = plt.figure(figsize=(20, 15))
sns.boxplot(x='bowling_team', y='Economy Rate', hue='Innings', data=powerplay_stats_df_v2)
plt.xlabel('Inning')
plt.ylabel('Score')
plt.xticks(rotation=90)
plt.title('Team Strike Rate by Inning')
plt.show()

# %%
powerplay_stats_df_v2_=powerplay_stats_df_v2.drop(['Player_of_Match', 'Team1Players', 'Team2Players', 'Umpire1',
       'Umpire2'],axis=1)
powerplay_stats_df_v2.columns
# Out:
# Index(['Powerplay Score', 'ID', 'Innings', 'Batter Strike Rate',
#        'Economy Rate', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'batting_team', 'bowling_team'],
#       dtype='object')

# %%
#drop rows with batting_team & bowling_team nan (ignore superovers)
final_powerplay_stats_df=powerplay_stats_df_v2_.dropna(subset=['batting_team', 'bowling_team'], inplace=False)
print(final_powerplay_stats_df.shape)
india_powerplay_data=final_powerplay_stats_df[~final_powerplay_stats_df['Season'].isin(['2009','2020/21'])]


train_features=['ID', 'Season','Innings','Powerplay Score', 'Venue','batting_team','bowling_team','Batter Strike Rate',
                'Economy Rate']

train_df=india_powerplay_data[train_features]

#train_df.isna().sum()
train_df
# Out:
# (1898, 20)
#            ID   Season  Innings  Powerplay Score  \
# 0      335982  2007/08        1               61
# 1      335982  2007/08        2               26
# 2      335983  2007/08        1               53
# 3      335983  2007/08        2               63
# 4      335984  2007/08        1               40
# ...       ...      ...      ...              ...
# 1923  1312198     2022        2               62
# 1924  1312199     2022        1               46
# 1925  1312199     2022        2               67
# 1926  1312200     2022        1               44
# 1927  1312200     2022        2               31
#
#                                    Venue                 batting_team  \
# 0                  M Chinnaswamy Stadium        Kolkata Knight Riders
# 1                  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 2     Punjab Cricket Association Stadium          Chennai Super Kings
# 3     Punjab Cricket Association Stadium                 Punjab Kings
# 4                       Feroz Shah Kotla             Rajasthan Royals
# ...                                  ...                          ...
# 1923                        Eden Gardens         Lucknow Super Giants
# 1924               Narendra Modi Stadium  Royal Challengers Bangalore
# 1925               Narendra Modi Stadium             Rajasthan Royals
# 1926               Narendra Modi Stadium             Rajasthan Royals
# 1927               Narendra Modi Stadium               Gujarat Titans
#
#                      bowling_team  Batter Strike Rate  Economy Rate
# 0     Royal Challengers Bangalore           83.333333      9.500000
# 1           Kolkata Knight Riders           41.666667      4.500000
# 2                    Punjab Kings          136.363636     10.500000
# 3             Chennai Super Kings          162.777778     10.500000
# 4                  Delhi Capitals          103.846154      4.333333
# ...                           ...                 ...           ...
# 1923  Royal Challengers Bangalore          143.137255     10.666667
# 1924  Royal Challengers Bangalore          107.692308      7.666667
# 1925  Royal Challengers Bangalore          161.538462     10.750000
# 1926               Gujarat Titans          137.500000      7.250000
# 1927             Rajasthan Royals           71.428571      6.000000
#
# [1664 rows x 9 columns]

# %%
train_df.columns
# Out:
# Index(['ID', 'Season', 'Innings', 'Powerplay Score', 'Venue', 'batting_team',
#        'bowling_team', 'Batter Strike Rate', 'Economy Rate'],
#       dtype='object')

# %%
import scipy.stats as stats

# %% [raw]
# # Perform t-test against a hypothesized population mean
# hypothesized_mean = round(train_df['Powerplay Score'].mean(),0) # Example hypothesized population mean
# sample_data_=train_df[train_df['Season'].isin(['2021','2022'])]
# t_stat, p_value = stats.ttest_1samp(sample_data_["Powerplay Score"], hypothesized_mean)
#
# # Print t-statistic and p-value
# print("T-Statistic: ", t_stat)
# print("P-Value: ", p_value)

# %%
# Create label encoder object
le = LabelEncoder()
#sample_data_=train_df[train_df['Season'].isin(['2021','2022'])]
sample_data_=train_df
sample_data=sample_data_[['Innings', 'Powerplay Score', 'Venue', 'batting_team',
       'bowling_team', 'Batter Strike Rate', 'Economy Rate']]
# Iterate through all the columns of the dataframe and encode the categorical variables
for col in sample_data.columns:
    if sample_data[col].dtype == 'object':
        sample_data[col] = le.fit_transform(sample_data[col])

num_cols = sample_data.select_dtypes(include=['int64', 'float64']).columns.tolist()
final_train_df_features_importance = sample_data[num_cols]

corr = sample_data.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# C:\Users\Sawon\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### Relationship Between Venue Batting Bowling Team & Venue

# %%
# Create a contingency table
data=train_df.copy(deep=True)
contingency_table = pd.crosstab(data["Venue"], [data["batting_team"], data["bowling_team"]])

# Perform chi-square test of independence
chi2_stat, p_value, dof, expected = stats.chi2_contingency(contingency_table)

# Print chi-square statistic, p-value, and degrees of freedom
print("Chi-Square Statistic: ", chi2_stat)
print("P-Value: ", p_value)
print("Degrees of Freedom: ", dof)

# Set significance level
alpha = 0.05

# Compare p-value with significance level
if p_value < alpha:
    print("Reject null hypothesis: There is a significant relationship between the three categorical variables.")
else:
    print("Fail to reject null hypothesis: There is no significant relationship between the three categorical variables.")
# Out:
# Chi-Square Statistic:  8492.274982833025
# P-Value:  0.0
# Degrees of Freedom:  3770
# Reject null hypothesis: There is a significant relationship between the three categorical variables.

# %% [raw]
# # Create a contingency table
# data=sample_data.copy(deep=True)
# contingency_table = pd.crosstab(data["Venue"], [data["batting_team"], data["bowling_team"]])
#
# # Perform chi-square test of independence
# chi2_stat, p_value, dof, expected = stats.chi2_contingency(contingency_table)
#
# # Print chi-square statistic, p-value, and degrees of freedom
# print("Chi-Square Statistic: ", chi2_stat)
# print("P-Value: ", p_value)
# print("Degrees of Freedom: ", dof)
#
# # Set significance level
# alpha = 0.05
#
# # Compare p-value with significance level
# if p_value < alpha:
#     print("Reject null hypothesis: There is a significant relationship between the three categorical variables.")
# else:
#     print("Fail to reject null hypothesis: There is no significant relationship between the three categorical variables.")

# %%
process_data_v0=train_df.copy(deep=True)
# %matplotlib inline
import matplotlib.pyplot as plt
process_data_v0.hist(bins=50, figsize=(20,15))

plt.show()

# %%
train_df_eda=train_df.copy(deep=True)

# %%
train_df_eda["Powerplay Score Cat"] = pd.cut(train_df_eda["Powerplay Score"],
                               bins=[train_df_eda['Powerplay Score'].min(),36,42,48,54,train_df_eda['Powerplay Score'].max()],
                               labels=['Very Low', 'Low', 'Moderate', 'High', 'Very High'])

sns.countplot(x='Powerplay Score Cat', data=train_df_eda)

# %%
train_df_eda.isna().sum()
# Out:
# ID                     0
# Season                 0
# Innings                0
# Powerplay Score        0
# Venue                  0
# batting_team           0
# bowling_team           0
# Batter Strike Rate     0
# Economy Rate           0
# Powerplay Score Cat    1
# dtype: int64

# %%
#train_df_eda[train_df_eda['Powerplay Score Cat'].isna()]
train_df_eda_=train_df_eda.dropna()
train_df_eda_
# Out:
#            ID   Season  Innings  Powerplay Score  \
# 0      335982  2007/08        1               61
# 1      335982  2007/08        2               26
# 2      335983  2007/08        1               53
# 3      335983  2007/08        2               63
# 4      335984  2007/08        1               40
# ...       ...      ...      ...              ...
# 1923  1312198     2022        2               62
# 1924  1312199     2022        1               46
# 1925  1312199     2022        2               67
# 1926  1312200     2022        1               44
# 1927  1312200     2022        2               31
#
#                                    Venue                 batting_team  \
# 0                  M Chinnaswamy Stadium        Kolkata Knight Riders
# 1                  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 2     Punjab Cricket Association Stadium          Chennai Super Kings
# 3     Punjab Cricket Association Stadium                 Punjab Kings
# 4                       Feroz Shah Kotla             Rajasthan Royals
# ...                                  ...                          ...
# 1923                        Eden Gardens         Lucknow Super Giants
# 1924               Narendra Modi Stadium  Royal Challengers Bangalore
# 1925               Narendra Modi Stadium             Rajasthan Royals
# 1926               Narendra Modi Stadium             Rajasthan Royals
# 1927               Narendra Modi Stadium               Gujarat Titans
#
#                      bowling_team  Batter Strike Rate  Economy Rate  \
# 0     Royal Challengers Bangalore           83.333333      9.500000
# 1           Kolkata Knight Riders           41.666667      4.500000
# 2                    Punjab Kings          136.363636     10.500000
# 3             Chennai Super Kings          162.777778     10.500000
# 4                  Delhi Capitals          103.846154      4.333333
# ...                           ...                 ...           ...
# 1923  Royal Challengers Bangalore          143.137255     10.666667
# 1924  Royal Challengers Bangalore          107.692308      7.666667
# 1925  Royal Challengers Bangalore          161.538462     10.750000
# 1926               Gujarat Titans          137.500000      7.250000
# 1927             Rajasthan Royals           71.428571      6.000000
#
#      Powerplay Score Cat
# 0              Very High
# 1               Very Low
# 2                   High
# 3              Very High
# 4                    Low
# ...                  ...
# 1923           Very High
# 1924            Moderate
# 1925           Very High
# 1926            Moderate
# 1927            Very Low
#
# [1663 rows x 10 columns]

# %% [markdown]
# ### Split the Dataset

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(train_df_eda_, train_df_eda_["Powerplay Score Cat"]):
    strat_train_set = train_df_eda_.iloc[train_index]
    strat_test_set = train_df_eda_.iloc[test_index]

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop("Powerplay Score Cat", axis=1, inplace=True)
# Out:
# C:\Users\Sawon\anaconda3\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
match_details = strat_train_set.drop("Powerplay Score", axis=1) # drop labels for training set
powerplay_score = strat_train_set["Powerplay Score"].copy()

# %%
match_details=match_details.drop(['ID','Season','Economy Rate'],axis=1)

# %%
match_details['Innings']=match_details['Innings'].astype(str)
match_details
# Out:
#      Innings                                    Venue  \
# 1262       1                               Green Park
# 1776       1                  Sharjah Cricket Stadium
# 1761       2      Dubai International Cricket Stadium
# 1863       2  Maharashtra Cricket Association Stadium
# 777        1       JSCA International Stadium Complex
# ...      ...                                      ...
# 608        2               Subrata Roy Sahara Stadium
# 1409       2                         Wankhede Stadium
# 1920       1                             Eden Gardens
# 75         2       Punjab Cricket Association Stadium
# 1088       1                         Feroz Shah Kotla
#
#                  batting_team                 bowling_team  Batter Strike Rate
# 1262           Gujarat Titans               Gujarat Titans          118.333333
# 1776           Delhi Capitals               Delhi Capitals           89.473684
# 1761           Mumbai Indians  Royal Challengers Bangalore          140.555556
# 1863             Punjab Kings         Lucknow Super Giants          142.857143
# 777   Rising Pune Supergiants        Kolkata Knight Riders          119.047619
# ...                       ...                          ...                 ...
# 608   Rising Pune Supergiants  Royal Challengers Bangalore          130.000000
# 1409           Mumbai Indians               Delhi Capitals          103.846154
# 1920         Rajasthan Royals             Rajasthan Royals           94.117647
# 75           Rajasthan Royals                 Punjab Kings           31.428571
# 1088           Gujarat Titans               Delhi Capitals          196.250000
#
# [1330 rows x 5 columns]

# %% [markdown]
# ### CUSTOM TRANSFORMER

# %% [raw]
# from sklearn.base import BaseEstimator, TransformerMixin
#
# # column index
# rooms_ix, bedrooms_ix, population_ix, households_ix = 3, 4, 5, 6
#
# class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
#     def __init__(self, add_bedrooms_per_room=True): # no *args or **kargs
#         self.add_bedrooms_per_room = add_bedrooms_per_room
#     def fit(self, X, y=None):
#         return self  # nothing else to do
#     def transform(self, X):
#         rooms_per_household = X[:, rooms_ix] / X[:, households_ix]
#         population_per_household = X[:, population_ix] / X[:, households_ix]
#         if self.add_bedrooms_per_room:
#             bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
#             return np.c_[X, rooms_per_household, population_per_household,
#                          bedrooms_per_room]
#         else:
#             return np.c_[X, rooms_per_household, population_per_household]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        #('attribs_adder', CombinedAttributesAdder()),
        ('std_scaler', StandardScaler()),
    ])

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.compose import ColumnTransformer

num_attribs = ['Batter Strike Rate']
cat_attribs = ['Innings','Venue','batting_team','bowling_team']

full_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
        ("cat", OneHotEncoder(), cat_attribs),
    ])

match_details_onehot_encoder = full_pipeline.fit_transform(match_details)
match_details_onehot_encoder.shape
# Out:
# (1330, 57)

# %% [markdown]
# ## Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(match_details_onehot_encoder, powerplay_score)
# Out:
# LinearRegression()

# %%
# let's try the full preprocessing pipeline on a few training instances
some_data = match_details.iloc[:5]
some_labels = powerplay_score.iloc[:5]
some_data_prepared = full_pipeline.transform(some_data)

print("Predictions:", lin_reg.predict(some_data_prepared))
print("Actual Score:", some_labels.values)
# Out:
# Predictions: [48.68569346 38.97187066 54.17067938 55.5656608  44.92464108]
# Actual Score: [50 38 56 46 42]

# %%
from sklearn.metrics import mean_squared_error

score_predictions = lin_reg.predict(match_details_onehot_encoder)
lin_mse = mean_squared_error(powerplay_score, score_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 6.8337180008737155

# %%
from sklearn.metrics import mean_absolute_error

lin_mae = mean_absolute_error(powerplay_score, score_predictions)
lin_mae
# Out:
# 5.140849157002508

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(match_details_onehot_encoder, powerplay_score)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
score_predictions = tree_reg.predict(match_details_onehot_encoder)
tree_mse = mean_squared_error(powerplay_score, score_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.5802730322701115

# %% [markdown]
# ### Better Evaluation Using Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_reg, match_details_onehot_encoder, powerplay_score,
                         scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [ 9.39934808 10.34444386 11.360878    9.20908391 11.97381228  8.8116251
#   8.57472437  9.3015481   9.45308956 12.86248845]
# Mean: 10.12910416979597
# Standard deviation: 1.3824127186215176

# %%
lin_scores = cross_val_score(lin_reg, match_details_onehot_encoder, powerplay_score,
                             scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [6.41276262 7.84108375 6.88103914 6.86748913 8.40310899 6.40069907
#  7.02957644 6.57843849 7.64218888 7.0763408 ]
# Mean: 7.113272731272678
# Standard deviation: 0.6229264095335261

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=100, random_state=42)
forest_reg.fit(match_details_onehot_encoder, powerplay_score)
# Out:
# RandomForestRegressor(random_state=42)

# %%
score_predictions = forest_reg.predict(match_details_onehot_encoder)
forest_mse = mean_squared_error(powerplay_score, score_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 2.884867031672722

# %%
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, match_details_onehot_encoder, powerplay_score,
                                scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [6.78925949 8.00258264 6.88356219 7.44258633 9.20570225 6.83872775
#  7.25228481 7.44808163 8.42871549 7.9825866 ]
# Mean: 7.627408918411345
# Standard deviation: 0.7405987251868126

# %%
scores = cross_val_score(lin_reg, match_details_onehot_encoder, powerplay_score, scoring="neg_mean_squared_error", cv=10)
pd.Series(np.sqrt(-scores)).describe()
# Out:
# count    10.000000
# mean      7.113273
# std       0.656622
# min       6.400699
# 25%       6.650701
# 50%       6.955308
# 75%       7.500727
# max       8.403109
# dtype: float64

# %%
from sklearn.svm import SVR

svm_reg = SVR(kernel="linear")
svm_reg.fit(match_details_onehot_encoder, powerplay_score)
score_predictions = svm_reg.predict(match_details_onehot_encoder)
svm_mse = mean_squared_error(powerplay_score, score_predictions)
svm_rmse = np.sqrt(svm_mse)
svm_rmse
# Out:
# 6.975881616105608

# %% [markdown]
# ## Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    # then try 6 (2×3) combinations with bootstrap set as False
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestRegressor(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)
grid_search.fit(match_details_onehot_encoder, powerplay_score)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30, random_state=42)

# %% [markdown]
# ### Grid Search CV

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 10.368138618860044 {'max_features': 2, 'n_estimators': 3}
# 9.504584665562767 {'max_features': 2, 'n_estimators': 10}
# 9.059143302055938 {'max_features': 2, 'n_estimators': 30}
# 9.655739029378934 {'max_features': 4, 'n_estimators': 3}
# 8.626856811227753 {'max_features': 4, 'n_estimators': 10}
# 8.363361614615675 {'max_features': 4, 'n_estimators': 30}
# 9.778917938764785 {'max_features': 6, 'n_estimators': 3}
# 8.605784029729431 {'max_features': 6, 'n_estimators': 10}
# 8.142420129967707 {'max_features': 6, 'n_estimators': 30}
# 9.050034193768665 {'max_features': 8, 'n_estimators': 3}
# 8.080742402895597 {'max_features': 8, 'n_estimators': 10}
# 7.870059221316842 {'max_features': 8, 'n_estimators': 30}
# 10.73924341871201 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 9.743947128299586 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 10.110166512378061 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# 9.406136259467141 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 10.119377261326871 {'bootstrap': False, 'max_features': 4, 'n_estimators': 3}
# 8.943277021579492 {'bootstrap': False, 'max_features': 4, 'n_estimators': 10}

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.028533      0.003677         0.004755        0.003884
# 1        0.066545      0.014128         0.006537        0.003269
# 2        0.175995      0.012453         0.004908        0.004012
# 3        0.024755      0.004124         0.002071        0.003103
# 4        0.078669      0.007383         0.002052        0.003100
# 5        0.183946      0.013206         0.009980        0.003286
# 6        0.028834      0.006403         0.006374        0.003188
# 7        0.066158      0.006109         0.003254        0.003987
# 8        0.220576      0.033319         0.008098        0.000179
# 9        0.026846      0.002814         0.003198        0.003917
# 10       0.080999      0.015621         0.001694        0.003388
# 11       0.194295      0.007896         0.009924        0.003177
# 12       0.029632      0.004392         0.001602        0.003203
# 13       0.076870      0.006391         0.003555        0.003666
# 14       0.023069      0.003284         0.003266        0.004001
# 15       0.085834      0.013958         0.003289        0.004028
# 16       0.022959      0.006232         0.003254        0.003986
# 17       0.085083      0.018248         0.001643        0.003286
#
#    param_max_features param_n_estimators param_bootstrap  \
# 0                   2                  3             NaN
# 1                   2                 10             NaN
# 2                   2                 30             NaN
# 3                   4                  3             NaN
# 4                   4                 10             NaN
# 5                   4                 30             NaN
# 6                   6                  3             NaN
# 7                   6                 10             NaN
# 8                   6                 30             NaN
# 9                   8                  3             NaN
# 10                  8                 10             NaN
# 11                  8                 30             NaN
# 12                  2                  3           False
# 13                  2                 10           False
# 14                  3                  3           False
# 15                  3                 10           False
# 16                  4                  3           False
# 17                  4                 10           False
#
#                                                params  split0_test_score  \
# 0              {'max_features': 2, 'n_estimators': 3}         -88.116678
# 1             {'max_features': 2, 'n_estimators': 10}         -79.341372
# 2             {'max_features': 2, 'n_estimators': 30}         -67.380748
# 3              {'max_features': 4, 'n_estimators': 3}         -90.716896
# 4             {'max_features': 4, 'n_estimators': 10}         -67.397837
# 5             {'max_features': 4, 'n_estimators': 30}         -60.627719
# 6              {'max_features': 6, 'n_estimators': 3}         -82.096700
# 7             {'max_features': 6, 'n_estimators': 10}         -68.190448
# 8             {'max_features': 6, 'n_estimators': 30}         -57.685339
# 9              {'max_features': 8, 'n_estimators': 3}         -76.912803
# 10            {'max_features': 8, 'n_estimators': 10}         -57.569881
# 11            {'max_features': 8, 'n_estimators': 30}         -53.599471
# 12  {'bootstrap': False, 'max_features': 2, 'n_est...        -125.269528
# 13  {'bootstrap': False, 'max_features': 2, 'n_est...         -88.024662
# 14  {'bootstrap': False, 'max_features': 3, 'n_est...         -86.142277
# 15  {'bootstrap': False, 'max_features': 3, 'n_est...         -75.943241
# 16  {'bootstrap': False, 'max_features': 4, 'n_est...         -94.924394
# 17  {'bootstrap': False, 'max_features': 4, 'n_est...         -66.627951
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0         -112.683166        -100.141604        -119.593486
# 1          -89.614199         -80.202001        -103.522417
# 2          -74.896891         -75.302890         -99.212972
# 3          -80.694027         -92.593150         -86.909171
# 4          -64.084038         -75.334858         -78.210561
# 5          -59.607072         -70.950518         -78.893614
# 6          -96.880518         -84.209273         -96.351527
# 7          -64.850349         -71.538651         -84.072681
# 8          -57.641596         -67.223495         -71.893142
# 9          -77.442565         -76.810777         -94.715260
# 10         -60.802272         -64.253145         -75.030672
# 11         -53.961295         -65.821633         -69.289179
# 12        -110.734754        -104.090330        -131.087824
# 13         -95.673797         -83.422820        -108.470508
# 14         -89.630221        -106.805764        -125.749907
# 15         -85.817786         -90.883797        -101.689916
# 16         -92.152151        -101.123329        -123.823099
# 17         -74.651266         -80.883929         -90.061680
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0         -116.956558      -107.498298       11.767780               17
# 1          -99.005659       -90.337130        9.727748               11
# 2          -93.546886       -82.068077       12.154191                9
# 3         -115.253237       -93.233296       11.737527               12
# 4          -87.085997       -74.422658        8.145866                6
# 5          -79.650165       -69.945817        8.590267                4
# 6         -118.598162       -95.627236       12.986178               14
# 7          -81.645466       -74.059519        7.528872                5
# 8          -77.051457       -66.299006        7.705975                3
# 9          -83.634190       -81.903119        6.897526                8
# 10         -68.836018       -65.298398        6.136279                2
# 11         -67.017582       -61.937832        6.754013                1
# 12        -105.474311      -115.331349       10.878275               18
# 13         -99.130742       -94.944506        8.736620               13
# 14        -102.749165      -102.215467       14.085179               15
# 15         -88.042256       -88.475399        8.303365               10
# 16         -99.986007      -102.401796       11.200978               16
# 17         -87.686194       -79.982204        8.585050                7
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0           -29.601563          -31.620102          -29.655493
# 1           -17.915226          -17.669018          -16.855046
# 2           -13.237629          -13.372150          -12.330967
# 3           -29.166630          -29.672212          -24.418338
# 4           -14.484067          -15.608876          -13.197073
# 5           -12.051508          -12.063721          -10.376105
# 6           -27.646907          -28.725052          -21.626149
# 7           -14.411969          -13.691395          -11.597322
# 8           -10.720801          -10.836076           -9.032161
# 9           -23.459114          -25.099594          -23.113513
# 10          -12.199651          -12.343944          -11.440242
# 11          -10.018548          -10.167850           -8.705527
# 12           -0.328791           -0.418599           -0.450658
# 13           -0.344124           -0.440937           -0.340962
# 14           -0.645572           -0.494622           -0.740654
# 15           -0.425891           -0.472544           -0.359196
# 16           -0.691155           -0.501932           -0.283156
# 17           -0.393466           -0.500986           -0.327951
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0           -29.008029          -25.908347        -29.158707         1.848725
# 1           -16.094112          -14.487860        -16.604252         1.237307
# 2           -12.533740          -12.394856        -12.773868         0.440565
# 3           -23.822948          -24.160877        -26.248201         2.601086
# 4           -12.568496          -11.696450        -13.510993         1.387617
# 5           -10.215412          -10.236478        -10.988645         0.874565
# 6           -22.030423          -21.879264        -24.381559         3.127620
# 7           -11.834557          -10.952717        -12.497592         1.321116
# 8            -9.166793           -9.310091         -9.813184         0.793851
# 9           -21.824074          -16.631753        -22.025610         2.892133
# 10          -10.912684          -10.631751        -11.505654         0.678817
# 11           -8.976366           -9.137734         -9.401205         0.583563
# 12           -0.209743           -0.539474         -0.389453         0.112319
# 13           -0.121148           -0.466327         -0.342700         0.121675
# 14           -0.269632           -0.455096         -0.521115         0.162475
# 15           -0.147177           -0.523991         -0.385760         0.131055
# 16           -0.228122           -0.468254         -0.434524         0.165563
# 17           -0.152581           -0.475702         -0.370137         0.124836

# %% [markdown]
# ### Randomized Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=200),
        'max_features': randint(low=1, high=8),
    }

forest_reg = RandomForestRegressor(random_state=42)
rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=42)
rnd_search.fit(match_details_onehot_encoder, powerplay_score)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#                    param_distributions={'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001FD9D014F48>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001FD9D014548>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 10.368138618860044 {'max_features': 2, 'n_estimators': 3}
# 9.504584665562767 {'max_features': 2, 'n_estimators': 10}
# 9.059143302055938 {'max_features': 2, 'n_estimators': 30}
# 9.655739029378934 {'max_features': 4, 'n_estimators': 3}
# 8.626856811227753 {'max_features': 4, 'n_estimators': 10}
# 8.363361614615675 {'max_features': 4, 'n_estimators': 30}
# 9.778917938764785 {'max_features': 6, 'n_estimators': 3}
# 8.605784029729431 {'max_features': 6, 'n_estimators': 10}
# 8.142420129967707 {'max_features': 6, 'n_estimators': 30}
# 9.050034193768665 {'max_features': 8, 'n_estimators': 3}
# 8.080742402895597 {'max_features': 8, 'n_estimators': 10}
# 7.870059221316842 {'max_features': 8, 'n_estimators': 30}
# 10.73924341871201 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 9.743947128299586 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 10.110166512378061 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# 9.406136259467141 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 10.119377261326871 {'bootstrap': False, 'max_features': 4, 'n_estimators': 3}
# 8.943277021579492 {'bootstrap': False, 'max_features': 4, 'n_estimators': 10}

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 7.867684030262933 {'max_features': 7, 'n_estimators': 180}
# 8.698273964845633 {'max_features': 5, 'n_estimators': 15}
# 8.603409800276719 {'max_features': 3, 'n_estimators': 72}
# 8.472141951382154 {'max_features': 5, 'n_estimators': 21}
# 7.89715431742283 {'max_features': 7, 'n_estimators': 122}
# 8.593202840176833 {'max_features': 3, 'n_estimators': 75}
# 8.589466010377853 {'max_features': 3, 'n_estimators': 88}
# 8.19492011865702 {'max_features': 5, 'n_estimators': 100}
# 8.595048220443335 {'max_features': 3, 'n_estimators': 150}
# 10.727354672160441 {'max_features': 5, 'n_estimators': 2}

# %%
feature_importances = rnd_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([0.65481757, 0.01003849, 0.01105294, 0.00474156, 0.00146605,
#        0.01078078, 0.00497005, 0.00262908, 0.0029684 , 0.00737423,
#        0.00612778, 0.00176926, 0.00332068, 0.00611782, 0.00413256,
#        0.00841222, 0.00771271, 0.00634012, 0.00128835, 0.00127224,
#        0.00371815, 0.0042947 , 0.00706169, 0.00257691, 0.00426794,
#        0.00513362, 0.00192041, 0.00373057, 0.00623041, 0.00321829,
#        0.00096854, 0.01072823, 0.00436977, 0.01244428, 0.00928638,
#        0.00509788, 0.00387415, 0.01033447, 0.00167735, 0.01029447,
#        0.01010361, 0.00860484, 0.0056488 , 0.00896739, 0.00941746,
#        0.00896485, 0.00757807, 0.0031818 , 0.00298139, 0.01001087,
#        0.00208212, 0.00871425, 0.01331777, 0.00918766, 0.0048803 ,
#        0.00992213, 0.00787559])

# %% [markdown]
# ## Final Score

# %%
final_model = rnd_search.best_estimator_

X_test_ = strat_test_set.drop("Powerplay Score", axis=1)
y_test = strat_test_set["Powerplay Score"].copy()

# %%
X_test_
# Out:
#            ID   Season  Innings                                Venue  \
# 1826  1304070     2022        1           Dr DY Patil Sports Academy
# 82     336023  2007/08        1               Sawai Mansingh Stadium
# 1908  1304111     2022        1                     Wankhede Stadium
# 1283  1082650     2017        2   Rajiv Gandhi International Stadium
# 838    729313     2014        2  Dubai International Cricket Stadium
# ...       ...      ...      ...                                  ...
# 926    829705     2015        2                         Eden Gardens
# 328    419153  2009/10        1               MA Chidambaram Stadium
# 278    419128  2009/10        1                M Chinnaswamy Stadium
# 313    419145  2009/10        2                M Chinnaswamy Stadium
# 1442  1178394     2019        1   Rajiv Gandhi International Stadium
#
#                  batting_team                 bowling_team  \
# 1826           Gujarat Titans               Gujarat Titans
# 82           Rajasthan Royals             Rajasthan Royals
# 1908      Sunrisers Hyderabad          Sunrisers Hyderabad
# 1283  Rising Pune Supergiants               Mumbai Indians
# 838              Punjab Kings  Royal Challengers Bangalore
# ...                       ...                          ...
# 926     Kolkata Knight Riders               Mumbai Indians
# 328     Kolkata Knight Riders          Chennai Super Kings
# 278            Delhi Capitals  Royal Challengers Bangalore
# 313       Sunrisers Hyderabad  Royal Challengers Bangalore
# 1442           Mumbai Indians               Mumbai Indians
#
#       Batter Strike Rate  Economy Rate
# 1826          112.500000      6.500000
# 82            106.793478      9.000000
# 1908          153.846154      8.500000
# 1283           50.000000      7.000000
# 838            50.000000      7.000000
# ...                  ...           ...
# 926            75.000000      5.000000
# 328            22.500000      3.666667
# 278           139.545455     10.750000
# 313            81.818182      5.833333
# 1442           83.035714      5.000000
#
# [333 rows x 8 columns]

# %%
X_test=X_test_.drop(['ID','Season','Economy Rate'],axis=1)
X_test['Innings']=X_test['Innings'].astype(str)

# %%
X_test_prepared = full_pipeline.transform(X_test)
final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
print(final_rmse)
# Out:
# 8.23643681959262

# %%
from scipy import stats

confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
np.sqrt(stats.t.interval(confidence, len(squared_errors) - 1,
                         loc=squared_errors.mean(),
                         scale=stats.sem(squared_errors)))
# Out:
# array([7.21958705, 9.14086133])

# %%
m = len(squared_errors)
mean = squared_errors.mean()
tscore = stats.t.ppf((1 + confidence) / 2, df=m - 1)
tmargin = tscore * squared_errors.std(ddof=1) / np.sqrt(m)
np.sqrt(mean - tmargin), np.sqrt(mean + tmargin)
# Out:
# (7.219587051266512, 9.140861325688459)

# %% [markdown]
# ### End of Modelling V1 with 6 Features (Innings	Venue	batting_team	bowling_team	Batter Strike Rate	Economy Rate)

# %% [markdown]
# ### Save the model
